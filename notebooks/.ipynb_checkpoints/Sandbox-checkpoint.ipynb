# %%
wd = pwd()
cd("..\\test")
include("runtests.jl")
cd(wd)
# Out:
# INFO: POMDPs.jl requirements for action(::AbstractMCTSPlanner, ::Any) and dependencies. ([✔] = implemented correctly; [X] = not implemented; [?] = could not determine)
#
# For action(::AbstractMCTSPlanner, ::Any):
#   [No additional requirements]
# For simulate(::AbstractMCTSPlanner, ::Any, ::Int64) (in action(::AbstractMCTSPlanner, ::Any)):
#   [✔] discount(::ASTMDP)
#   [✔] isterminal(::ASTMDP, ::ASTState)
#   [?] gen(::DDNOut{(:sp, :r)}, ::ASTMDP, ::ASTState, ::ASTAction, ::MersenneTwister)
#   [✔] isequal(::ASTState, ::ASTState)
#   [✔] hash(::ASTState)
# For insert_node!(::MCTSPlanner{Main.POMDPStressTesting.AST.ASTMDPMain.POMDPStressTesting.AST.ASTStateMain.POMDPStressTesting.AST.ASTActionMCTS.SolvedRolloutEstimator{POMDPPolicies.RandomPolicy{Random.MersenneTwister,Main.POMDPStressTesting.AST.ASTMDP,BeliefUpdaters.NothingUpdater},Random.MersenneTwister}Random.MersenneTwister}, ::ASTState) (in simulate(::AbstractMCTSPlanner, ::Any, ::Int64)):
#   [No requirements specified]
# ...

# %%
using D3Trees
state = AST.ASTState(1, nothing, AST.ASTAction(AST.RSG())) 
# D3Tree(policy, state, init_expand=2)
D3Tree(policy)
# Out:
# MCTSPlanner{ASTMDP,ASTState,ASTAction,SolvedRolloutEstimator{RandomPolicy{MersenneTwister,ASTMDP,NothingUpdater},MersenneTwister},MersenneTwister}(MCTSSolver(100, 10, 1.0, MersenneTwister(UInt32[0xc3cbcb3f, 0xdf27cbd1, 0x30ea4871, 0x00e0f94c], DSFMT_state(Int32[787953922, 1072845304, -1159899423, 1072801642, 1277096992, 1072915209, 353552050, 1072917289, -347349819, 1073316664, -2082964565, 1073526652, -128901673, 1073328661, -608194132, 1072804608, -1079803355, 1073353384, -620372497, 1073512224, 418835835, 1073397455, -391429252, 1072939827, 358517141, 1073537093, 985418633, 1073124840, -881053242, 1072798982, -1216357095, 1073591396, -1122420617, 1073264999, -2090119811, 1073563032, -245919201, 1073599825, -335660997, 1073188314, 763481524, 1073153785, -1787605749, 1073309435, 107020898, 1073243271, -1184695484, 1073661905, -1240868642, 1073078440, 1714474098, 1073032220, -2082704570, 1073726626, 469022789, 1073557683, -497379196, 1072779790, 730461585, 1072850024, 738751170, 1073
# ...
