# %%
wd = pwd()
cd("..\\test")
include("Walk1D.jl")
cd(wd)

display(HTML("<style>.container { width:100% !important; }</style>")) # Full width cells

function MCTS.node_tag(s::AST.ASTState)
#     if s.done
#         return "done"
#     else
        return "0x"*string(s.hash, base=16)
#     end
end

seeds2string(a) = join(map(s->"0x" * string(s, base=16), a.rsg.state), ",\n")
function MCTS.node_tag(a::AST.ASTAction)
    if a == action # selected optimal action
        return "—[$(seeds2string(a))]—"
    else
        return "[$(seeds2string(a))]"
    end
end
# Out:
# evaluation error starting at C:\Users\mossr\.julia\packages\Parameters\l76EM\src\Parameters.jl:570
#   invalid redefinition of constant Params
# Stacktrace:
#  [1] top-level scope at C:\Users\mossr\.julia\packages\IJulia\F1GUo\src\kernel.jl:52
# while evaluating
# begin
#     #= C:\Users\mossr\Code\sisl\ast\POMDPStressTesting.jl\src\AST.jl:63 =#
#     #= C:\Users\mossr\Code\sisl\ast\POMDPStressTesting.jl\src\AST.jl:68 =# @with_kw mutable struct Params
#             #= C:\Users\mossr\Code\sisl\ast\POMDPStressTesting.jl\src\AST.jl:69 =#
#             max_steps::Int64 = 0
#             #= C:\Users\mossr\Code\sisl\ast\POMDPStressTesting.jl\src\AST.jl:70 =#
#             rsg_length::Int64 = 3
#             #= C:\Users\mossr\Code\sisl\ast\POMDPStressTesting.jl\src\AST.jl:71 =#
#             init_seed::Int64 = 0
#             #= C:\Users\mossr\Code\sisl\ast\POMDPStressTesting.jl\src\AST.jl:72 =#
#             reset_seed::Union{Nothing, Int64} = nothing
# ...

# %%
using D3Trees
using POMDPSimulators

# TODO: follow deterministic rollout!
# rollout = 

state = initialstate(mdp)
(action,info) = action_info(planner, state, tree_in_info=true)
d3 = D3Tree(info[:tree], init_expand=1)

action_path = AST.get_optimal_path(mdp, info[:tree], initialstate(mdp), verbose=true)
# AST.playback(mdp, action_path)

d3
# Out:
# State = 0xc586ef06d338b447	:	Q = -35.1847562854324	:	Action = UInt32[0x8fa665b3, 0xf347b878]
# State = 0xfa7cffdabf398fce	:	Q = -32.604027641302444	:	Action = UInt32[0x6d92d180, 0x588f4a85]
# State = 0xbb88a27cd4c14893	:	Q = -29.93738571375575	:	Action = UInt32[0x37ee13d8, 0x120c69e1]
# State = 0x371ccc4b67e7e43e	:	Q = -37.35095164920894	:	Action = UInt32[0xced93de7, 0xb04c335e]
# State = 0x665124aa490f76cf	:	End of tree.
#        0xc586ef06d338b447
# N:    100
#
# ├──   [0x6afe0bea,
# │  0x1a23ebf]
# │  Q: -39.79
# │  N:      4
#
# │  └──       0xc193598876609d48
# │     N:      3
#
# │     └──  [0x7f0c141b,
# │        0x96e0db60]
# │        Q: -38.58
# │        N:      3
#  (1 children)
# ├──  [0x7f5f1e95,
# │  0x9f6b9a8e]
# │  Q: -44.67
# │  N:      4
#
# │  └──       0xc9d2c3a3382527bc
# │     N:      3
#
# │     └──  [0xdae5e40c,
# │        0x7ca84509]
# │        Q: -45.53
# │        N:      3
#  (1 children)
# ├──  [0x79820b8d,
# │  0x62217c6c]
# │  Q: -40.34
# │  N:      4
#
# ...

# %%
S = POMDPStressTesting.AST.ASTState(26, 0xeb323859eb10445f, POMDPStressTesting.AST.ASTState(25, 0x68c2e7dc98fe3d18, POMDPStressTesting.AST.ASTState(24, 0x02f41e3230253f04, POMDPStressTesting.AST.ASTState(23, 0xf0ca9b9b75f1b476, POMDPStressTesting.AST.ASTState(22, 0x43ede1b5466b2a2d, POMDPStressTesting.AST.ASTState(21, 0xbe348ae2110fc216, POMDPStressTesting.AST.ASTState(20, 0x9d1d8c7f969e02cb, POMDPStressTesting.AST.ASTState(19, 0x178cf7b736690646, POMDPStressTesting.AST.ASTState(18, 0xd94180da9b9588b7, POMDPStressTesting.AST.ASTState(17, 0x98afb76700a10a11, POMDPStressTesting.AST.ASTState(16, 0xebfa640f717ae749, POMDPStressTesting.AST.ASTState(15, 0xbedff8ab778e76b2, POMDPStressTesting.AST.ASTState(14, 0xc4e6f100f28e8141, POMDPStressTesting.AST.ASTState(13, 0x98f2346edf96b4ac, POMDPStressTesting.AST.ASTState(12, 0x76daf7389ffeecdc, POMDPStressTesting.AST.ASTState(11, 0x980d5fa2f4e14000, POMDPStressTesting.AST.ASTState(10, 0x0b2648bed05189e3, POMDPStressTesting.AST.ASTState(9, 0xae89e824c87bda01, POMDPStressTesting.AST.ASTState(8, 0x0793356f156d209f, POMDPStressTesting.AST.ASTState(7, 0xb90acc262100f5f5, POMDPStressTesting.AST.ASTState(6, 0xe82393d074fccff1, POMDPStressTesting.AST.ASTState(5, 0xcee1bc44386fd91f, POMDPStressTesting.AST.ASTState(4, 0x879e54729f8cbae6, POMDPStressTesting.AST.ASTState(3, 0x5f0587ee5284d3f2, POMDPStressTesting.AST.ASTState(2, 0x971bf4db6ed6ad54, POMDPStressTesting.AST.ASTState(1, 0xc586ef06d338b447, nothing, POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0x00000001, 0x4bce797f])), 0.0), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0x6b8cae73, 0x0eed067c])), -0.9789028750861333), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0x0eed067c, 0x6d6b5ee1])), -1.5324203401668703), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0x6d6b5ee1, 0x7aa2365c])), -2.4485891175080554), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0x7aa2365c, 0x0bfc7cb6])), -1.6767706848852078), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0x0bfc7cb6, 0x43e3ed28])), -0.9452156375431768), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0x43e3ed28, 0xa45da41b])), -0.9367940863712569), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0xa45da41b, 0xb8ba2fa7])), -0.9493879260922804), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0xb8ba2fa7, 0x7d19279f])), -1.5017876250668751), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0x7d19279f, 0x860de0cc])), -2.4202287320539777), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0x860de0cc, 0x0e012984])), -0.9981376881130379), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0x0e012984, 0x5de774de])), -0.9959776547616329), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0x5de774de, 0x9d59de58])), -1.55367325683609), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0x9d59de58, 0x40ab866c])), -3.1942007069358427), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0x40ab866c, 0x28093559])), -2.0173480440805758), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0x28093559, 0xf2168193])), -1.065453772414256), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0xf2168193, 0x8606156b])), -2.026378886342146), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0x8606156b, 0x41540458])), -1.3976125145927911), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0x41540458, 0x0d4cfe36])), -1.251260288219045), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0x0d4cfe36, 0x8fd3bd6f])), -1.013147948615615), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0x8fd3bd6f, 0x8fb5f65b])), -1.1205458895455525), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0x8fb5f65b, 0xa828a80e])), -0.9309205370303976), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0xa828a80e, 0x8adf2000])), -1.2712602982152152), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0x8adf2000, 0xe708dce3])), -0.9190021001146191), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0xe708dce3, 0x7fb508b9])), -1.0586678762861401), POMDPStressTesting.AST.ASTAction(POMDPStressTesting.AST.RandomSeedGenerator.RSG(UInt32[0x7fb508b9, 0xb9744148])), -8.030887281067189)

# function q_trace(s)
#     q_values = [s.action]
#     while !isnothing(s.parent)
#         prepend!(actions, [s.parent.action])
#         s = s.parent
#     end
    
#     return actions
# end

states = AST.state_trace(S)
actions = AST.action_trace(S)
q_value = AST.q_trace(S)

for s in states
    @show s.q_value
end

@show q_value
# for a in actions
#     @show a.rsg.state
# end

# s.action
# Out:
# s.q_value = 0.0
# s.q_value = -0.9789028750861333
# s.q_value = -1.5324203401668703
# s.q_value = -2.4485891175080554
# s.q_value = -1.6767706848852078
# s.q_value = -0.9452156375431768
# s.q_value = -0.9367940863712569
# s.q_value = -0.9493879260922804
# s.q_value = -1.5017876250668751
# s.q_value = -2.4202287320539777
# s.q_value = -0.9981376881130379
# s.q_value = -0.9959776547616329
# s.q_value = -1.55367325683609
# s.q_value = -3.1942007069358427
# s.q_value = -2.0173480440805758
# s.q_value = -1.065453772414256
# s.q_value = -2.026378886342146
# s.q_value = -1.3976125145927911
# s.q_value = -1.251260288219045
# s.q_value = -1.013147948615615
# s.q_value = -1.1205458895455525
# s.q_value = -0.9309205370303976
# s.q_value = -1.2712602982152152
# s.q_value = -0.9190021001146191
# s.q_value = -1.0586678762861401
# s.q_value = -8.030887281067189
# q_value = -42.23457176794398
# -42.23457176794398

# %%
# AST.playback(mdp, collect(keys(mdp.top_paths))[end])
display(collect(values(mdp.top_paths)))
# @show BlackBox.isevent(mdp.sim)
# display(mdp.sim.history)

for A in collect(keys(mdp.top_paths))
    println("———[",  ,"]———")
    AST.playback(mdp, A)    
end
# Out:
# 10-element Array{Float64,1}:
#  -26.33679382415722
#  -25.568329164008144
#  -25.22187406357176
#  -23.78288328753297
#  -22.63351643426878
#  -22.5888593686619
#  -22.507571095569922
#  -22.169796793531113
#  -21.92896660998443
#  -16.815310017076946
# mdp.sim.x = 1.0
# mdp.sim.x = 3.3648214471446494
# mdp.sim.x = 3.632897359310559
# mdp.sim.x = 2.999286643636776
# mdp.sim.x = 3.709386889109949
# mdp.sim.x = 3.493323002997684
# mdp.sim.x = 4.35647425569052
# mdp.sim.x = 4.864955619424392
# mdp.sim.x = 6.515424193197502
# mdp.sim.x = 6.458260754298455
# mdp.sim.x = 6.812102933518798
# mdp.sim.x = 6.702885307463671
# mdp.sim.x = 7.121439228944897
# mdp.sim.x = 7.923413320046584
# mdp.sim.x = 8.491833319596225
# mdp.sim.x = 9.459913459230146
# mdp.sim.x = 9.307934960238436
# mdp.sim.x = 9.562651807521974
# mdp.sim.x = 12.197139999203372
# ———|———
# mdp.sim.x = 1.0
# mdp.sim.x = 2.257066949399907
# mdp.sim.x = 1.387689415350736
# mdp.sim.x = 2.1611413512873305
# ...

# %%
collect(keys(mdp.top_paths))[end-5]
# Out:
# BoundsError: attempt to access 0-element Array{Any,1} at index [-5]
#
# Stacktrace:
#  [1] getindex(::Array{Any,1}, ::Int64) at .\array.jl:728
#  [2] top-level scope at In[5]:1

# %%
# Follow MCTS policy online.
online_actions = AST.online_path(mdp, planner);
# Out:
# UndefVarError: ancestor_actions not defined
#
# Stacktrace:
#  [1] record_trace(::POMDPStressTesting.AST.ASTMDP, ::Array{POMDPStressTesting.AST.ASTAction,1}, ::Float64) at C:\Users\mossr\Code\sisl\ast\POMDPStressTesting.jl\src\AST.jl:346
#  [2] go_to_state(::POMDPStressTesting.AST.ASTMDP, ::POMDPStressTesting.AST.ASTState) at C:\Users\mossr\Code\sisl\ast\POMDPStressTesting.jl\src\AST.jl:337
#  [3] rollout(::POMDPStressTesting.AST.ASTMDP, ::POMDPStressTesting.AST.ASTState, ::Int64) at C:\Users\mossr\Code\sisl\ast\POMDPStressTesting.jl\src\AST.jl:361
#  [4] rollout(::POMDPStressTesting.AST.ASTMDP, ::POMDPStressTesting.AST.ASTState, ::Int64) at C:\Users\mossr\Code\sisl\ast\POMDPStressTesting.jl\src\AST.jl:367 (repeats 13 times)
#  [5] estimate_value at C:\Users\mossr\.julia\dev\MCTS\src\domain_knowledge.jl:8 [inlined]
# ...

# %%
AST.playback(mdp, online_actions)
# Out:
# UndefVarError: online_actions not defined
#
# Stacktrace:
#  [1] top-level scope at In[7]:1
